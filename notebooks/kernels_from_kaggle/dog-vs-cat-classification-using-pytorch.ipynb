# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['dogs-vs-cats', 'dogs-vs-cats-for-pytorch']

# %%
from os import walk
for (dirpath, dirnames, filenames) in walk("../input/dogs-vs-cats"):
    print("Directory path: ", dirpath)
    print("Folder name: ", dirnames)
    print("File name: ", filenames)
# Out:
# Directory path:  ../input/dogs-vs-cats
# Folder name:  ['train', 'test1']
# File name:  ['sampleSubmission.csv']
# Directory path:  ../input/dogs-vs-cats/train
# Folder name:  ['train']
# File name:  []
# Directory path:  ../input/dogs-vs-cats/train/train
# Folder name:  []
# File name:  ['cat.11679.jpg', 'dog.2811.jpg', 'dog.2578.jpg', 'dog.9238.jpg', 'dog.7504.jpg', 'dog.11302.jpg', 'dog.11743.jpg', 'cat.8233.jpg', 'cat.1653.jpg', 'cat.12144.jpg', 'dog.634.jpg', 'cat.2354.jpg', 'cat.1097.jpg', 'cat.7757.jpg', 'dog.1038.jpg', 'cat.4755.jpg', 'dog.9031.jpg', 'cat.6217.jpg', 'dog.9326.jpg', 'dog.5225.jpg', 'cat.3745.jpg', 'dog.1171.jpg', 'dog.5806.jpg', 'cat.5632.jpg', 'dog.10270.jpg', 'cat.2277.jpg', 'cat.952.jpg', 'dog.9791.jpg', 'cat.9311.jpg', 'cat.2505.jpg', 'cat.8848.jpg', 'dog.489.jpg', 'dog.2907.jpg', 'dog.7340.jpg', 'cat.6801.jpg', 'dog.928.jpg', 'dog.12072.jpg', 'cat.9701.jpg', 'dog.1961.jpg', 'dog.10853.jpg', 'cat.11450.jpg', 'cat.6351.jpg', 'cat.8458.jpg', 'dog.3403.jpg', 'cat.5266.jpg', 'cat.6682.jpg', 'dog.12166.jpg', 'cat.10286.jpg', 'dog.6251.jpg', 'dog.9228.jpg', 'cat.3436.jpg', 'dog.11880.jpg', 'dog.5181.jpg', 'dog.4827.jpg', 'dog.8061.jpg', 'dog.8851.jpg', 'cat.3090.jpg', 'cat.10018.jpg', 'cat.415.jpg', 'cat.1584.jpg', 'cat.9818.jpg', 'cat.162.jpg', 'dog.9711.jpg', 'dog.8744.jpg', 'dog.4288.jpg', 'cat.4208.jpg', 'dog.2727.jpg', 'cat.7560.jpg', 'cat.1178.jpg', 'dog.10673.jpg', 'cat.7976.jpg', 'dog.5555.jpg', 'dog.2077.jpg', 'cat.1145.jpg', 'cat.5219.jpg', 'dog.6082.jpg', 'cat.7474.jpg', 'cat.11092.jpg', 'dog.9863.jpg', 'cat.8883.jpg', 'dog.5954.jpg', 'dog.7161.jpg', 'dog.8076.jpg', 'dog.2092.jpg', 'dog.4536.jpg', 'dog.5399.jpg', 'dog.4380.jpg', 'dog.11670.jpg', 'dog.3470.jpg', 'dog.6263.jpg', 'cat.4538.jpg', 'cat.1801.jpg', 'cat.9825.jpg', 'dog.6296.jpg', 'dog.5907.jpg', 'cat.1143.jpg', 'dog.605.jpg', 'dog.8648.jpg', 'cat.6199.jpg', 'dog.8261.jpg', 'cat.6701.jpg', 'cat.7545.jpg', 'dog.9866.jpg', 'cat.5757.jpg', 'cat.9005.jpg', 'dog.6055.jpg', 'cat.4012.jpg', 'dog.7085.jpg', 'dog.9190.jpg', 'cat.4142.jpg', 'dog.107.jpg', 'dog.2483.jpg', 'dog.10660.jpg', 'cat.2595.jpg', 'dog.9995.jpg', 'dog.7469.jpg', 'dog.3750.jpg', 'dog.5267.jpg', 'dog.10404.jpg', 'cat.11768.jpg', 'dog.11235.jpg', 'dog.4643.jpg', 'dog.2004.jpg', 'dog.11135.jpg', 'dog.7603.jpg', 'cat.2219.jpg', 'cat.10490.jpg', 'cat.11359.jpg', 'cat.6299.jpg', 'cat.5492.jpg', 'dog.2358.jpg', 'dog.7880.jpg', 'dog.5855.jpg', 'cat.8363.jpg', 'cat.7593.jpg', 'cat.64.jpg', 'cat.9129.jpg', 'cat.10913.jpg', 'cat.10863.jpg', 'dog.9538.jpg', 'cat.11446.jpg', 'cat.12107.jpg', 'cat.4788.jpg', 'dog.11757.jpg', 'dog.8006.jpg', 'dog.8080.jpg', 'dog.7660.jpg', 'cat.4406.jpg', 'dog.3439.jpg', 'dog.4096.jpg', 'cat.11140.jpg', 'cat.12440.jpg', 'dog.9065.jpg', 'cat.6493.jpg', 'dog.1725.jpg', 'dog.5995.jpg', 'cat.9981.jpg', 'dog.11762.jpg', 'cat.5328.jpg', 'dog.5915.jpg', 'cat.10059.jpg', 'dog.176.jpg', 'cat.5512.jpg', 'dog.56.jpg', 'dog.10662.jpg', 'dog.8587.jpg', 'dog.9687.jpg', 'dog.11118.jpg', 'cat.7287.jpg', 'dog.11988.jpg', 'cat.11490.jpg', 'dog.9982.jpg', 'cat.5900.jpg', 'dog.4809.jpg', 'dog.4895.jpg', 'cat.11229.jpg', 'dog.5397.jpg', 'cat.4139.jpg', 'dog.10604.jpg', 'dog.10318.jpg', 'cat.3512.jpg', 'dog.7481.jpg', 'dog.8213.jpg', 'cat.7828.jpg', 'cat.4252.jpg', 'cat.7231.jpg', 'cat.4998.jpg', 'cat.2569.jpg', 'cat.1678.jpg', 'dog.2156.jpg', 'cat.11169.jpg', 'cat.3097.jpg', 'cat.1784.jpg', 'dog.767.jpg', 'cat.7052.jpg', 'dog.4171.jpg', 'cat.6061.jpg', 'dog.9852.jpg', 'dog.341.jpg', 'dog.11870.jpg', 'dog.10473.jpg', 'cat.12401.jpg', 'dog.9196.jpg', 'dog.1600.jpg', 'dog.7170.jpg', 'cat.8961.jpg', 'cat.5749.jpg', 'dog.7312.jpg', 'dog.10912.jpg', 'dog.7204.jpg', 'cat.6381.jpg', 'dog.10634.jpg', 'dog.10933.jpg', 'cat.11826.jpg', 'cat.2645.jpg', 'dog.9905.jpg', 'dog.8586.jpg', 'cat.7818.jpg', 'cat.3324.jpg', 'dog.1203.jpg', 'cat.9328.jpg', 'cat.12182.jpg', 'cat.8370.jpg', 'dog.7511.jpg', 'dog.6986.jpg', 'dog.21.jpg', 'cat.1500.jpg', 'cat.7599.jpg', 'dog.7057.jpg', 'dog.8745.jpg', 'cat.1221.jpg', 'cat.9537.jpg', 'cat.10397.jpg', 'cat.4350.jpg', 'cat.7878.jpg', 'dog.9390.jpg', 'cat.11943.jpg', 'cat.10395.jpg', 'cat.304.jpg', 'dog.3235.jpg', 'cat.4363.jpg', 'cat.2764.jpg', 'dog.2713.jpg', 'cat.6316.jpg', 'cat.12102.jpg', 'cat.119.jpg', 'cat.2555.jpg', 'ca ...
# Directory path:  ../input/dogs-vs-cats/test1
# Folder name:  ['test1']
# File name:  []
# Directory path:  ../input/dogs-vs-cats/test1/test1
# Folder name:  []
# File name:  ['3090.jpg', '8785.jpg', '10679.jpg', '7247.jpg', '8151.jpg', '1621.jpg', '10255.jpg', '7723.jpg', '11953.jpg', '6162.jpg', '11721.jpg', '5833.jpg', '3898.jpg', '5674.jpg', '12333.jpg', '2136.jpg', '2633.jpg', '2638.jpg', '11391.jpg', '10058.jpg', '8271.jpg', '8720.jpg', '4253.jpg', '10286.jpg', '3148.jpg', '5929.jpg', '4196.jpg', '7316.jpg', '11652.jpg', '3261.jpg', '2546.jpg', '4257.jpg', '4591.jpg', '10927.jpg', '3268.jpg', '2047.jpg', '2762.jpg', '11769.jpg', '12377.jpg', '9200.jpg', '1638.jpg', '8988.jpg', '513.jpg', '5860.jpg', '4412.jpg', '5723.jpg', '6417.jpg', '1689.jpg', '3733.jpg', '39.jpg', '9115.jpg', '1284.jpg', '1667.jpg', '3299.jpg', '3359.jpg', '1797.jpg', '12323.jpg', '5000.jpg', '6675.jpg', '2640.jpg', '10373.jpg', '3113.jpg', '12328.jpg', '5244.jpg', '1231.jpg', '11772.jpg', '6336.jpg', '1118.jpg', '11153.jpg', '9056.jpg', '1734.jpg', '10341.jpg', '2472.jpg', '9213.jpg', '10037.jpg', '11884.jpg', '3863.jpg', '2503.jpg', '5394.jpg', '7829.jpg', '8028.jpg', '1061.jpg', '9495.jpg', '11157.jpg', '10063.jpg', '8637.jpg', '2204.jpg', '7141.jpg', '6103.jpg', '6523.jpg', '12314.jpg', '8465.jpg', '4718.jpg', '3609.jpg', '4011.jpg', '5002.jpg', '2602.jpg', '747.jpg', '3676.jpg', '8115.jpg', '10867.jpg', '1230.jpg', '6476.jpg', '12155.jpg', '4806.jpg', '2982.jpg', '11735.jpg', '5661.jpg', '9723.jpg', '4023.jpg', '11299.jpg', '6094.jpg', '150.jpg', '11830.jpg', '5641.jpg', '10295.jpg', '1074.jpg', '6338.jpg', '4450.jpg', '7948.jpg', '2954.jpg', '8850.jpg', '3427.jpg', '364.jpg', '1148.jpg', '10706.jpg', '12243.jpg', '2636.jpg', '7378.jpg', '11003.jpg', '1890.jpg', '3971.jpg', '8568.jpg', '9467.jpg', '7497.jpg', '10226.jpg', '11096.jpg', '8952.jpg', '5330.jpg', '5952.jpg', '5937.jpg', '6829.jpg', '3068.jpg', '11480.jpg', '1835.jpg', '2545.jpg', '653.jpg', '6927.jpg', '4136.jpg', '8413.jpg', '2095.jpg', '8335.jpg', '5575.jpg', '9541.jpg', '1109.jpg', '5493.jpg', '2231.jpg', '2808.jpg', '12341.jpg', '10696.jpg', '4390.jpg', '10133.jpg', '4743.jpg', '6181.jpg', '10484.jpg', '9845.jpg', '5425.jpg', '2715.jpg', '4383.jpg', '3095.jpg', '5409.jpg', '3966.jpg', '10205.jpg', '4751.jpg', '9242.jpg', '9951.jpg', '199.jpg', '2518.jpg', '8503.jpg', '8806.jpg', '12340.jpg', '6212.jpg', '5424.jpg', '2016.jpg', '2871.jpg', '9594.jpg', '7471.jpg', '4347.jpg', '8150.jpg', '11495.jpg', '12240.jpg', '5310.jpg', '7947.jpg', '5689.jpg', '2349.jpg', '6499.jpg', '9276.jpg', '11829.jpg', '5923.jpg', '6558.jpg', '1489.jpg', '428.jpg', '12433.jpg', '146.jpg', '6140.jpg', '6111.jpg', '281.jpg', '6508.jpg', '5403.jpg', '12235.jpg', '2026.jpg', '865.jpg', '7093.jpg', '129.jpg', '10265.jpg', '1863.jpg', '2858.jpg', '2468.jpg', '3087.jpg', '2861.jpg', '5252.jpg', '2815.jpg', '4903.jpg', '8581.jpg', '7376.jpg', '9371.jpg', '1135.jpg', '2656.jpg', '1829.jpg', '6842.jpg', '11131.jpg', '3172.jpg', '5075.jpg', '7126.jpg', '2360.jpg', '5405.jpg', '758.jpg', '552.jpg', '10877.jpg', '7243.jpg', '6497.jpg', '5215.jpg', '10422.jpg', '1579.jpg', '9473.jpg', '6995.jpg', '9486.jpg', '2298.jpg', '2822.jpg', '1395.jpg', '3312.jpg', '2562.jpg', '7050.jpg', '1839.jpg', '1159.jpg', '8385.jpg', '12218.jpg', '9249.jpg', '5138.jpg', '3222.jpg', '6883.jpg', '1298.jpg', '9904.jpg', '1819.jpg', '9983.jpg', '4791.jpg', '7988.jpg', '4876.jpg', '11293.jpg', '12473.jpg', '7745.jpg', '1299.jpg', '9364.jpg', '6460.jpg', '6810.jpg', '10531.jpg', '4894.jpg', '2294.jpg', '7361.jpg', '12131.jpg', '1706.jpg', '11995.jpg', '7842.jpg', '8607.jpg', '8307.jpg', '12059.jpg', '10427.jpg', '1795.jpg', '11943.jpg', '7880.jpg', '9328.jpg', '1704.jpg', '5013.jpg', '10070.jpg', '373.jpg', '10455.jpg', '930.jpg', '901.jpg', '7573.jpg', '1183.jpg', '8960.jpg', '8931.jpg', '7120.jpg', '1215.jpg', '6314.jpg', '1552.jpg', '10932.jpg', '3838.jpg', '9178.jpg', '11377.jpg', '1524.jpg', '665.jpg', '7827.jpg', '2480.jpg', '7145.jpg', '2697.jpg', '10339.jpg', '5887.jpg', '445.jpg', '9135.jpg', '3341.jpg', '2216.jpg', '1125.jpg', '5114.jpg', '8797.jpg', '4065.jpg', '12492.jpg', '892.jpg', '6623.j ...

# %%
from os import walk
for (dirpath, dirnames, filenames) in walk("../input/dogs-vs-cats-for-pytorch"):
    print("Directory path: ", dirpath)
    print("Folder name: ", dirnames)
    print("File name: ", filenames)
# Out:
# Directory path:  ../input/dogs-vs-cats-for-pytorch
# Folder name:  ['cat_dog_data']
# File name:  []
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data
# Folder name:  ['Cat_Dog_data']
# File name:  []
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data
# Folder name:  ['train', 'test']
# File name:  []
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/train
# Folder name:  ['cat', 'dog']
# File name:  []
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/train/cat
# Folder name:  []
# File name:  ['cat.11679.jpg', 'cat.8233.jpg', 'cat.1653.jpg', 'cat.12144.jpg', 'cat.2354.jpg', 'cat.1097.jpg', 'cat.7757.jpg', 'cat.4755.jpg', 'cat.6217.jpg', 'cat.3745.jpg', 'cat.5632.jpg', 'cat.2277.jpg', 'cat.952.jpg', 'cat.9311.jpg', 'cat.2505.jpg', 'cat.8848.jpg', 'cat.9701.jpg', 'cat.11450.jpg', 'cat.6351.jpg', 'cat.8458.jpg', 'cat.5266.jpg', 'cat.6682.jpg', 'cat.10286.jpg', 'cat.3436.jpg', 'cat.3090.jpg', 'cat.10018.jpg', 'cat.415.jpg', 'cat.1584.jpg', 'cat.9818.jpg', 'cat.162.jpg', 'cat.4208.jpg', 'cat.7560.jpg', 'cat.1178.jpg', 'cat.7976.jpg', 'cat.1145.jpg', 'cat.5219.jpg', 'cat.7474.jpg', 'cat.11092.jpg', 'cat.1801.jpg', 'cat.9825.jpg', 'cat.1143.jpg', 'cat.6199.jpg', 'cat.6701.jpg', 'cat.7545.jpg', 'cat.9005.jpg', 'cat.4012.jpg', 'cat.4142.jpg', 'cat.11768.jpg', 'cat.2219.jpg', 'cat.10490.jpg', 'cat.11359.jpg', 'cat.6299.jpg', 'cat.5492.jpg', 'cat.8363.jpg', 'cat.7593.jpg', 'cat.64.jpg', 'cat.9129.jpg', 'cat.10913.jpg', 'cat.10863.jpg', 'cat.11446.jpg', 'cat.12107.jpg', 'cat.4788.jpg', 'cat.4406.jpg', 'cat.11140.jpg', 'cat.12440.jpg', 'cat.6493.jpg', 'cat.9981.jpg', 'cat.5328.jpg', 'cat.10059.jpg', 'cat.11490.jpg', 'cat.5900.jpg', 'cat.11229.jpg', 'cat.4139.jpg', 'cat.3512.jpg', 'cat.7828.jpg', 'cat.4252.jpg', 'cat.7231.jpg', 'cat.2569.jpg', 'cat.1678.jpg', 'cat.11169.jpg', 'cat.3097.jpg', 'cat.1784.jpg', 'cat.6061.jpg', 'cat.12401.jpg', 'cat.8961.jpg', 'cat.5749.jpg', 'cat.6381.jpg', 'cat.11826.jpg', 'cat.2645.jpg', 'cat.7818.jpg', 'cat.12182.jpg', 'cat.1500.jpg', 'cat.7599.jpg', 'cat.1221.jpg', 'cat.9537.jpg', 'cat.10397.jpg', 'cat.4350.jpg', 'cat.7878.jpg', 'cat.11943.jpg', 'cat.10395.jpg', 'cat.304.jpg', 'cat.4363.jpg', 'cat.2764.jpg', 'cat.6316.jpg', 'cat.12102.jpg', 'cat.119.jpg', 'cat.2555.jpg', 'cat.1497.jpg', 'cat.733.jpg', 'cat.747.jpg', 'cat.7885.jpg', 'cat.3327.jpg', 'cat.1990.jpg', 'cat.984.jpg', 'cat.2071.jpg', 'cat.3299.jpg', 'cat.2715.jpg', 'cat.3112.jpg', 'cat.4579.jpg', 'cat.5693.jpg', 'cat.8128.jpg', 'cat.2832.jpg', 'cat.8688.jpg', 'cat.10891.jpg', 'cat.9085.jpg', 'cat.7066.jpg', 'cat.6272.jpg', 'cat.6839.jpg', 'cat.11355.jpg', 'cat.4325.jpg', 'cat.724.jpg', 'cat.10143.jpg', 'cat.10259.jpg', 'cat.7044.jpg', 'cat.5981.jpg', 'cat.2242.jpg', 'cat.8366.jpg', 'cat.11303.jpg', 'cat.7939.jpg', 'cat.7439.jpg', 'cat.691.jpg', 'cat.4863.jpg', 'cat.8475.jpg', 'cat.11629.jpg', 'cat.3514.jpg', 'cat.2682.jpg', 'cat.932.jpg', 'cat.10123.jpg', 'cat.7155.jpg', 'cat.104.jpg', 'cat.12333.jpg', 'cat.2802.jpg', 'cat.4810.jpg', 'cat.593.jpg', 'cat.2417.jpg', 'cat.2999.jpg', 'cat.5960.jpg', 'cat.9191.jpg', 'cat.2677.jpg', 'cat.4377.jpg', 'cat.4549.jpg', 'cat.6503.jpg', 'cat.12033.jpg', 'cat.7444.jpg', 'cat.5415.jpg', 'cat.11915.jpg', 'cat.7892.jpg', 'cat.10650.jpg', 'cat.9241.jpg', 'cat.2873.jpg', 'cat.3925.jpg', 'cat.6644.jpg', 'cat.1083.jpg', 'cat.2077.jpg', 'cat.4809.jpg', 'cat.4681.jpg', 'cat.7527.jpg', 'cat.10156.jpg', 'cat.217.jpg', 'cat.8492.jpg', 'cat.5887.jpg', 'cat.6500.jpg', 'cat.10317.jpg', 'cat.3407.jpg', 'cat.6605.jpg', 'cat.7299.jpg', 'cat.6490.jpg', 'cat.8157.jpg', 'cat.3777.jpg', 'cat.9587.jpg', 'cat.7667.jpg', 'cat.24.jpg', 'cat.7676.jpg', 'cat.8512.jpg', 'cat.8266.jpg', 'cat.10353.jpg', 'cat.5427.jpg', 'cat.1789.jpg', 'cat.6074.jpg', 'cat.8621.jpg', 'cat.11852.jpg', 'cat.11820.jpg', 'cat.8981.jpg', 'cat.8649.jpg', 'cat.5386.jpg', 'cat.2838.jpg', 'cat.3752.jpg', 'cat.11381.jpg', 'cat.12460.jpg', 'cat.6356.jpg', 'cat.6224.jpg', 'cat.1069.jpg', 'cat.1086.jpg', 'cat.3490.jpg', 'cat.3739.jpg', 'cat.8306.jpg', 'cat.7791.jpg', 'cat.2045.jpg', 'cat.2890.jpg', 'cat.2876.jpg', 'cat.6561.jpg', 'cat.2016.jpg', 'cat.10171.jpg', 'cat.4842.jpg', 'cat.12202.jpg', 'cat.4454.jpg', 'cat.251.jpg', 'cat.1688.jpg', 'cat.10676.jpg', 'cat.8184.jpg', 'cat.2593.jpg', 'cat.11914.jpg', 'cat.7631.jpg', 'cat.12232.jpg', 'cat.2434.jpg', 'cat.6144.jpg', 'cat.4657.jpg', 'cat.10489.jpg', 'cat.7808.jpg', 'cat.883.jpg', 'cat.364.jpg', 'cat.5901.jpg', 'cat.2415.jpg', 'cat.11420.jpg', 'cat.5451.jpg', 'cat.10350.jpg', 'cat.9278.jpg', 'cat ...
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/train/dog
# Folder name:  []
# File name:  ['dog.2811.jpg', 'dog.2578.jpg', 'dog.9238.jpg', 'dog.7504.jpg', 'dog.11302.jpg', 'dog.11743.jpg', 'dog.634.jpg', 'dog.1038.jpg', 'dog.9031.jpg', 'dog.9326.jpg', 'dog.5225.jpg', 'dog.5806.jpg', 'dog.10270.jpg', 'dog.9791.jpg', 'dog.489.jpg', 'dog.7340.jpg', 'dog.928.jpg', 'dog.12072.jpg', 'dog.1961.jpg', 'dog.10853.jpg', 'dog.3403.jpg', 'dog.12166.jpg', 'dog.6251.jpg', 'dog.11880.jpg', 'dog.5181.jpg', 'dog.4827.jpg', 'dog.8061.jpg', 'dog.8851.jpg', 'dog.9711.jpg', 'dog.8744.jpg', 'dog.4288.jpg', 'dog.2727.jpg', 'dog.10673.jpg', 'dog.2077.jpg', 'dog.6082.jpg', 'dog.9863.jpg', 'dog.5954.jpg', 'dog.7161.jpg', 'dog.8076.jpg', 'dog.2092.jpg', 'dog.5399.jpg', 'dog.11670.jpg', 'dog.3470.jpg', 'dog.6263.jpg', 'dog.6296.jpg', 'dog.5907.jpg', 'dog.605.jpg', 'dog.8648.jpg', 'dog.8261.jpg', 'dog.9866.jpg', 'dog.6055.jpg', 'dog.7085.jpg', 'dog.9190.jpg', 'dog.107.jpg', 'dog.2483.jpg', 'dog.10660.jpg', 'dog.9995.jpg', 'dog.7469.jpg', 'dog.3750.jpg', 'dog.5267.jpg', 'dog.10404.jpg', 'dog.11235.jpg', 'dog.2004.jpg', 'dog.11135.jpg', 'dog.2358.jpg', 'dog.7880.jpg', 'dog.5855.jpg', 'dog.9538.jpg', 'dog.8006.jpg', 'dog.8080.jpg', 'dog.3439.jpg', 'dog.4096.jpg', 'dog.9065.jpg', 'dog.1725.jpg', 'dog.5995.jpg', 'dog.11762.jpg', 'dog.5915.jpg', 'dog.176.jpg', 'dog.56.jpg', 'dog.10662.jpg', 'dog.8587.jpg', 'dog.9687.jpg', 'dog.9982.jpg', 'dog.4809.jpg', 'dog.4895.jpg', 'dog.5397.jpg', 'dog.10318.jpg', 'dog.7481.jpg', 'dog.8213.jpg', 'dog.2156.jpg', 'dog.767.jpg', 'dog.4171.jpg', 'dog.9852.jpg', 'dog.341.jpg', 'dog.11870.jpg', 'dog.10473.jpg', 'dog.9196.jpg', 'dog.1600.jpg', 'dog.7170.jpg', 'dog.7312.jpg', 'dog.10912.jpg', 'dog.7204.jpg', 'dog.10634.jpg', 'dog.10933.jpg', 'dog.8586.jpg', 'dog.1203.jpg', 'dog.7511.jpg', 'dog.21.jpg', 'dog.7057.jpg', 'dog.8745.jpg', 'dog.9390.jpg', 'dog.3235.jpg', 'dog.2713.jpg', 'dog.293.jpg', 'dog.11400.jpg', 'dog.10978.jpg', 'dog.9380.jpg', 'dog.8182.jpg', 'dog.103.jpg', 'dog.10297.jpg', 'dog.1054.jpg', 'dog.6703.jpg', 'dog.1448.jpg', 'dog.4681.jpg', 'dog.9529.jpg', 'dog.334.jpg', 'dog.3682.jpg', 'dog.1255.jpg', 'dog.11721.jpg', 'dog.6169.jpg', 'dog.9582.jpg', 'dog.539.jpg', 'dog.4831.jpg', 'dog.10045.jpg', 'dog.1918.jpg', 'dog.6669.jpg', 'dog.12.jpg', 'dog.9838.jpg', 'dog.7107.jpg', 'dog.1183.jpg', 'dog.1119.jpg', 'dog.12118.jpg', 'dog.12321.jpg', 'dog.2822.jpg', 'dog.8211.jpg', 'dog.11840.jpg', 'dog.9868.jpg', 'dog.7866.jpg', 'dog.2954.jpg', 'dog.4403.jpg', 'dog.8991.jpg', 'dog.6150.jpg', 'dog.5691.jpg', 'dog.658.jpg', 'dog.102.jpg', 'dog.10080.jpg', 'dog.8641.jpg', 'dog.8982.jpg', 'dog.10686.jpg', 'dog.11042.jpg', 'dog.11085.jpg', 'dog.3996.jpg', 'dog.5801.jpg', 'dog.8143.jpg', 'dog.4202.jpg', 'dog.2818.jpg', 'dog.7576.jpg', 'dog.4893.jpg', 'dog.6531.jpg', 'dog.7091.jpg', 'dog.10892.jpg', 'dog.12106.jpg', 'dog.11104.jpg', 'dog.876.jpg', 'dog.535.jpg', 'dog.1936.jpg', 'dog.4650.jpg', 'dog.5459.jpg', 'dog.4479.jpg', 'dog.7791.jpg', 'dog.5799.jpg', 'dog.82.jpg', 'dog.4937.jpg', 'dog.12280.jpg', 'dog.11432.jpg', 'dog.2161.jpg', 'dog.9315.jpg', 'dog.7300.jpg', 'dog.7529.jpg', 'dog.7192.jpg', 'dog.3863.jpg', 'dog.8731.jpg', 'dog.932.jpg', 'dog.4778.jpg', 'dog.8271.jpg', 'dog.4307.jpg', 'dog.11408.jpg', 'dog.2808.jpg', 'dog.3149.jpg', 'dog.4435.jpg', 'dog.7233.jpg', 'dog.3801.jpg', 'dog.10140.jpg', 'dog.9603.jpg', 'dog.2783.jpg', 'dog.6136.jpg', 'dog.34.jpg', 'dog.11844.jpg', 'dog.7410.jpg', 'dog.8407.jpg', 'dog.5290.jpg', 'dog.2563.jpg', 'dog.7143.jpg', 'dog.19.jpg', 'dog.6382.jpg', 'dog.7358.jpg', 'dog.1430.jpg', 'dog.10188.jpg', 'dog.2755.jpg', 'dog.10269.jpg', 'dog.2122.jpg', 'dog.11831.jpg', 'dog.1934.jpg', 'dog.1889.jpg', 'dog.9671.jpg', 'dog.11151.jpg', 'dog.137.jpg', 'dog.1234.jpg', 'dog.1793.jpg', 'dog.9801.jpg', 'dog.7849.jpg', 'dog.7770.jpg', 'dog.5504.jpg', 'dog.8883.jpg', 'dog.9554.jpg', 'dog.3856.jpg', 'dog.982.jpg', 'dog.6297.jpg', 'dog.4579.jpg', 'dog.3752.jpg', 'dog.1042.jpg', 'dog.3193.jpg', 'dog.8136.jpg', 'dog.203.jpg', 'dog.12289.jpg', 'dog.8352.jpg', 'dog.11244.jpg', 'dog.1680.jpg', 'dog ...
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/test
# Folder name:  ['cat', 'dog']
# File name:  []
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/test/cat
# Folder name:  []
# File name:  ['cat.6801.jpg', 'cat.8883.jpg', 'cat.4538.jpg', 'cat.5757.jpg', 'cat.2595.jpg', 'cat.5512.jpg', 'cat.7287.jpg', 'cat.4998.jpg', 'cat.7052.jpg', 'cat.3324.jpg', 'cat.9328.jpg', 'cat.8370.jpg', 'cat.5003.jpg', 'cat.7233.jpg', 'cat.4340.jpg', 'cat.4076.jpg', 'cat.2937.jpg', 'cat.3187.jpg', 'cat.11687.jpg', 'cat.11333.jpg', 'cat.5406.jpg', 'cat.627.jpg', 'cat.3772.jpg', 'cat.10009.jpg', 'cat.7158.jpg', 'cat.4264.jpg', 'cat.692.jpg', 'cat.10063.jpg', 'cat.11073.jpg', 'cat.9327.jpg', 'cat.4846.jpg', 'cat.11560.jpg', 'cat.9430.jpg', 'cat.1346.jpg', 'cat.9219.jpg', 'cat.12364.jpg', 'cat.9243.jpg', 'cat.680.jpg', 'cat.10224.jpg', 'cat.5045.jpg', 'cat.2675.jpg', 'cat.12393.jpg', 'cat.10696.jpg', 'cat.12121.jpg', 'cat.10987.jpg', 'cat.9831.jpg', 'cat.10439.jpg', 'cat.2509.jpg', 'cat.3221.jpg', 'cat.11024.jpg', 'cat.8543.jpg', 'cat.5038.jpg', 'cat.7458.jpg', 'cat.4884.jpg', 'cat.11001.jpg', 'cat.3013.jpg', 'cat.5642.jpg', 'cat.3116.jpg', 'cat.3931.jpg', 'cat.4082.jpg', 'cat.5608.jpg', 'cat.2094.jpg', 'cat.1441.jpg', 'cat.10968.jpg', 'cat.1469.jpg', 'cat.11480.jpg', 'cat.10078.jpg', 'cat.10821.jpg', 'cat.7223.jpg', 'cat.3652.jpg', 'cat.5394.jpg', 'cat.1025.jpg', 'cat.12291.jpg', 'cat.7000.jpg', 'cat.6714.jpg', 'cat.2935.jpg', 'cat.783.jpg', 'cat.1080.jpg', 'cat.8612.jpg', 'cat.257.jpg', 'cat.11872.jpg', 'cat.4775.jpg', 'cat.6670.jpg', 'cat.9679.jpg', 'cat.16.jpg', 'cat.10859.jpg', 'cat.8829.jpg', 'cat.2594.jpg', 'cat.11477.jpg', 'cat.9621.jpg', 'cat.7909.jpg', 'cat.11670.jpg', 'cat.8799.jpg', 'cat.1284.jpg', 'cat.11068.jpg', 'cat.12371.jpg', 'cat.6738.jpg', 'cat.8231.jpg', 'cat.10654.jpg', 'cat.4425.jpg', 'cat.5097.jpg', 'cat.6638.jpg', 'cat.5856.jpg', 'cat.4861.jpg', 'cat.10667.jpg', 'cat.6317.jpg', 'cat.7020.jpg', 'cat.9485.jpg', 'cat.2680.jpg', 'cat.8880.jpg', 'cat.892.jpg', 'cat.3655.jpg', 'cat.1860.jpg', 'cat.6309.jpg', 'cat.10670.jpg', 'cat.12155.jpg', 'cat.11190.jpg', 'cat.1530.jpg', 'cat.11614.jpg', 'cat.10662.jpg', 'cat.6936.jpg', 'cat.4195.jpg', 'cat.5445.jpg', 'cat.4777.jpg', 'cat.6110.jpg', 'cat.134.jpg', 'cat.1722.jpg', 'cat.2703.jpg', 'cat.11409.jpg', 'cat.1962.jpg', 'cat.7063.jpg', 'cat.3788.jpg', 'cat.5707.jpg', 'cat.6251.jpg', 'cat.1743.jpg', 'cat.1563.jpg', 'cat.9746.jpg', 'cat.906.jpg', 'cat.5015.jpg', 'cat.669.jpg', 'cat.8665.jpg', 'cat.7238.jpg', 'cat.5690.jpg', 'cat.10893.jpg', 'cat.3481.jpg', 'cat.2780.jpg', 'cat.8706.jpg', 'cat.5409.jpg', 'cat.809.jpg', 'cat.4597.jpg', 'cat.12078.jpg', 'cat.3986.jpg', 'cat.4541.jpg', 'cat.2158.jpg', 'cat.695.jpg', 'cat.5599.jpg', 'cat.9510.jpg', 'cat.3864.jpg', 'cat.10254.jpg', 'cat.4059.jpg', 'cat.12481.jpg', 'cat.8916.jpg', 'cat.9487.jpg', 'cat.1933.jpg', 'cat.8614.jpg', 'cat.7250.jpg', 'cat.2587.jpg', 'cat.12369.jpg', 'cat.9908.jpg', 'cat.4570.jpg', 'cat.8138.jpg', 'cat.12172.jpg', 'cat.9267.jpg', 'cat.6599.jpg', 'cat.6035.jpg', 'cat.2901.jpg', 'cat.4375.jpg', 'cat.2851.jpg', 'cat.7566.jpg', 'cat.4464.jpg', 'cat.8754.jpg', 'cat.5931.jpg', 'cat.6733.jpg', 'cat.4982.jpg', 'cat.8381.jpg', 'cat.2548.jpg', 'cat.6078.jpg', 'cat.9893.jpg', 'cat.10505.jpg', 'cat.6911.jpg', 'cat.3733.jpg', 'cat.7185.jpg', 'cat.11729.jpg', 'cat.10851.jpg', 'cat.10669.jpg', 'cat.5509.jpg', 'cat.2439.jpg', 'cat.12014.jpg', 'cat.11411.jpg', 'cat.12124.jpg', 'cat.3302.jpg', 'cat.3547.jpg', 'cat.5425.jpg', 'cat.11116.jpg', 'cat.4423.jpg', 'cat.6178.jpg', 'cat.10613.jpg', 'cat.5846.jpg', 'cat.1310.jpg', 'cat.4845.jpg', 'cat.9108.jpg', 'cat.3791.jpg', 'cat.2539.jpg', 'cat.10615.jpg', 'cat.7481.jpg', 'cat.9033.jpg', 'cat.9989.jpg', 'cat.6711.jpg', 'cat.10609.jpg', 'cat.8529.jpg', 'cat.433.jpg', 'cat.861.jpg', 'cat.5455.jpg', 'cat.11810.jpg', 'cat.9398.jpg', 'cat.10240.jpg', 'cat.9570.jpg', 'cat.10032.jpg', 'cat.6517.jpg', 'cat.1863.jpg', 'cat.7311.jpg', 'cat.3629.jpg', 'cat.2377.jpg', 'cat.10061.jpg', 'cat.7454.jpg', 'cat.4143.jpg', 'cat.5078.jpg', 'cat.6542.jpg', 'cat.12075.jpg', 'cat.10309.jpg', 'cat.6584.jpg', 'cat.9156.jpg', 'cat.6193.jpg', 'cat.1774.jpg', 'cat.11036.jpg', 'cat.9664.jpg', 'cat.902 ...
# Directory path:  ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/test/dog
# Folder name:  []
# File name:  ['dog.1171.jpg', 'dog.2907.jpg', 'dog.9228.jpg', 'dog.5555.jpg', 'dog.4536.jpg', 'dog.4380.jpg', 'dog.4643.jpg', 'dog.7603.jpg', 'dog.11757.jpg', 'dog.7660.jpg', 'dog.11118.jpg', 'dog.11988.jpg', 'dog.10604.jpg', 'dog.9905.jpg', 'dog.6986.jpg', 'dog.6898.jpg', 'dog.567.jpg', 'dog.5370.jpg', 'dog.6693.jpg', 'dog.11848.jpg', 'dog.9376.jpg', 'dog.6056.jpg', 'dog.1348.jpg', 'dog.11684.jpg', 'dog.9245.jpg', 'dog.861.jpg', 'dog.4026.jpg', 'dog.8844.jpg', 'dog.7696.jpg', 'dog.955.jpg', 'dog.6632.jpg', 'dog.1808.jpg', 'dog.8017.jpg', 'dog.994.jpg', 'dog.8240.jpg', 'dog.9360.jpg', 'dog.6792.jpg', 'dog.10594.jpg', 'dog.8224.jpg', 'dog.10939.jpg', 'dog.8890.jpg', 'dog.5890.jpg', 'dog.6114.jpg', 'dog.8997.jpg', 'dog.3460.jpg', 'dog.11051.jpg', 'dog.1529.jpg', 'dog.4988.jpg', 'dog.2413.jpg', 'dog.10683.jpg', 'dog.10322.jpg', 'dog.6494.jpg', 'dog.2564.jpg', 'dog.11261.jpg', 'dog.9020.jpg', 'dog.3024.jpg', 'dog.8110.jpg', 'dog.5777.jpg', 'dog.9558.jpg', 'dog.7404.jpg', 'dog.2007.jpg', 'dog.4666.jpg', 'dog.8839.jpg', 'dog.6376.jpg', 'dog.7397.jpg', 'dog.8151.jpg', 'dog.6945.jpg', 'dog.5497.jpg', 'dog.7255.jpg', 'dog.1707.jpg', 'dog.1355.jpg', 'dog.6379.jpg', 'dog.5022.jpg', 'dog.9169.jpg', 'dog.11922.jpg', 'dog.5563.jpg', 'dog.10795.jpg', 'dog.2823.jpg', 'dog.3017.jpg', 'dog.1915.jpg', 'dog.10302.jpg', 'dog.4138.jpg', 'dog.9497.jpg', 'dog.5618.jpg', 'dog.338.jpg', 'dog.4840.jpg', 'dog.9996.jpg', 'dog.6484.jpg', 'dog.9679.jpg', 'dog.10530.jpg', 'dog.7064.jpg', 'dog.6683.jpg', 'dog.3216.jpg', 'dog.11554.jpg', 'dog.9445.jpg', 'dog.8686.jpg', 'dog.12477.jpg', 'dog.553.jpg', 'dog.6140.jpg', 'dog.6121.jpg', 'dog.8351.jpg', 'dog.5238.jpg', 'dog.1154.jpg', 'dog.5808.jpg', 'dog.10640.jpg', 'dog.9955.jpg', 'dog.2213.jpg', 'dog.5438.jpg', 'dog.8045.jpg', 'dog.1088.jpg', 'dog.11930.jpg', 'dog.12470.jpg', 'dog.3133.jpg', 'dog.9872.jpg', 'dog.10679.jpg', 'dog.1149.jpg', 'dog.2283.jpg', 'dog.1994.jpg', 'dog.11665.jpg', 'dog.852.jpg', 'dog.4999.jpg', 'dog.7272.jpg', 'dog.10828.jpg', 'dog.5050.jpg', 'dog.5810.jpg', 'dog.8935.jpg', 'dog.9428.jpg', 'dog.4214.jpg', 'dog.10108.jpg', 'dog.10936.jpg', 'dog.11914.jpg', 'dog.10691.jpg', 'dog.8216.jpg', 'dog.3893.jpg', 'dog.9805.jpg', 'dog.9610.jpg', 'dog.6293.jpg', 'dog.1876.jpg', 'dog.6714.jpg', 'dog.9672.jpg', 'dog.8650.jpg', 'dog.5634.jpg', 'dog.7573.jpg', 'dog.12201.jpg', 'dog.8738.jpg', 'dog.9257.jpg', 'dog.11655.jpg', 'dog.12413.jpg', 'dog.5790.jpg', 'dog.10198.jpg', 'dog.4351.jpg', 'dog.11614.jpg', 'dog.6817.jpg', 'dog.6430.jpg', 'dog.11899.jpg', 'dog.7874.jpg', 'dog.9580.jpg', 'dog.6800.jpg', 'dog.1103.jpg', 'dog.8875.jpg', 'dog.9496.jpg', 'dog.860.jpg', 'dog.9893.jpg', 'dog.3390.jpg', 'dog.11861.jpg', 'dog.1354.jpg', 'dog.7299.jpg', 'dog.9141.jpg', 'dog.4786.jpg', 'dog.4846.jpg', 'dog.4907.jpg', 'dog.8940.jpg', 'dog.9874.jpg', 'dog.2016.jpg', 'dog.12003.jpg', 'dog.503.jpg', 'dog.4610.jpg', 'dog.752.jpg', 'dog.9111.jpg', 'dog.496.jpg', 'dog.2018.jpg', 'dog.6011.jpg', 'dog.1773.jpg', 'dog.5120.jpg', 'dog.5177.jpg', 'dog.3544.jpg', 'dog.896.jpg', 'dog.1638.jpg', 'dog.9307.jpg', 'dog.5586.jpg', 'dog.5476.jpg', 'dog.8784.jpg', 'dog.11771.jpg', 'dog.72.jpg', 'dog.9611.jpg', 'dog.7041.jpg', 'dog.5757.jpg', 'dog.4102.jpg', 'dog.1094.jpg', 'dog.7775.jpg', 'dog.6579.jpg', 'dog.11527.jpg', 'dog.11796.jpg', 'dog.7602.jpg', 'dog.11131.jpg', 'dog.10770.jpg', 'dog.2152.jpg', 'dog.6602.jpg', 'dog.10681.jpg', 'dog.10942.jpg', 'dog.3730.jpg', 'dog.8996.jpg', 'dog.4562.jpg', 'dog.877.jpg', 'dog.7733.jpg', 'dog.8568.jpg', 'dog.10203.jpg', 'dog.6000.jpg', 'dog.5614.jpg', 'dog.1824.jpg', 'dog.1899.jpg', 'dog.3538.jpg', 'dog.7426.jpg', 'dog.11750.jpg', 'dog.3762.jpg', 'dog.9167.jpg', 'dog.10723.jpg', 'dog.7183.jpg', 'dog.6617.jpg', 'dog.4269.jpg', 'dog.1108.jpg', 'dog.2429.jpg', 'dog.4980.jpg', 'dog.7325.jpg', 'dog.2909.jpg', 'dog.1192.jpg', 'dog.7156.jpg', 'dog.7182.jpg', 'dog.507.jpg', 'dog.114.jpg', 'dog.9910.jpg', 'dog.10401.jpg', 'dog.5055.jpg', 'dog.1017.jpg', 'dog.5028.jpg', 'dog.11917.jpg', 'dog.597.jpg', 'dog. ...

# %% [markdown]
# Implementation

# %%
import torch
import torch.nn as nn
from torchvision import datasets ,models,transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torch.optim import lr_scheduler
from pathlib import Path
from matplotlib import pyplot as plt
import numpy as np

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
PATH=Path('../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data')
PATH1=Path('../input/dogs-vs-cats/test1')

# %%
TRAIN =Path(PATH/'train')
VALID = Path(PATH/'test')
TEST=Path(PATH1)
print(TRAIN)
print(VALID)
print(TEST)
# Out:
# ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/train
# ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/test
# ../input/dogs-vs-cats/test1

# %% [markdown]
# No of dog images for training

# %%
ls ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/train/dog -1 | wc -l
# Out:
# 11250

# %% [markdown]
# No of Cat images for training

# %%
ls ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/train/cat -1 | wc -l
# Out:
# 11250

# %% [markdown]
# No of Dog images for validation

# %%
ls ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/test/dog -1 | wc -l
# Out:
# 1250

# %% [markdown]
# No of Cat images for validation

# %%
ls ../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/test/cat -1 | wc -l
# Out:
# 1250

# %% [markdown]
# No of images to predict

# %%
ls ../input/dogs-vs-cats/test1/test1 -1 | wc -l
# Out:
# 12500

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 32

# convert data to a normalized torch.FloatTensor
train_transforms = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

valid_transforms = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])
# choose the training and test datasets

test_transforms = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])
# choose the training and test datasets
train_data = datasets.ImageFolder(TRAIN, transform=train_transforms)
valid_data=datasets.ImageFolder(VALID,transform=valid_transforms)
test_data = datasets.ImageFolder(PATH1, transform=test_transforms)

# obtain training indices that will be used for validation
#num_train = len(train_data)
#indices = list(range(num_train))
#np.random.shuffle(indices)
#split = int(np.floor(valid_size * num_train))
#print("Split Index",split)
#train_idx, valid_idx = indices[split:], indices[:split]
# define samplers for obtaining training and validation batches

# %%
print(train_data.class_to_idx)
print(valid_data.class_to_idx)
# Out:
# {'cat': 0, 'dog': 1}
# {'cat': 0, 'dog': 1}

# %%
# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers,shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size,  num_workers=num_workers,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,  num_workers=num_workers)

# %%
images,labels=next(iter(train_loader))

# %%
images.shape,labels.shape
# Out:
# (torch.Size([32, 3, 224, 224]), torch.Size([32]))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
classes = ['cat','dog']
mean , std = torch.tensor([0.485, 0.456, 0.406]),torch.tensor([0.229, 0.224, 0.225])


def denormalize(image):
  image = transforms.Normalize(-mean/std,1/std)(image) #denormalize
  image = image.permute(1,2,0) #Changing from 3x224x224 to 224x224x3
  image = torch.clamp(image,0,1)
  return image

# helper function to un-normalize and display an image
def imshow(img):
    img = denormalize(img) 
    plt.imshow(img)

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
 # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 8))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ".format( classes[labels[idx]]))

# %% [markdown]
# rgb_img = np.squeeze(images[3])
# channels = ['red channel', 'green channel', 'blue channel']
#
# fig = plt.figure(figsize = (36, 36))
# for idx in np.arange(rgb_img.shape[0]):
#     ax = fig.add_subplot(1, 3, idx + 1)
#     img = rgb_img[idx]
#     ax.imshow(img, cmap='gray')
#     ax.set_title(channels[idx])
#     width, height = img.shape
#     thresh = img.max()/2.5
#     for x in range(width):
#         for y in range(height):
#             val = round(img[x][y],2) if img[x][y] !=0 else 0
#             ax.annotate(str(val), xy=(y,x),
#                     horizontalalignment='center',
#                     verticalalignment='center', size=8,
#                     color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ![](http://)Load the model VGG -19

# %%
vgg_19=models.vgg19_bn(pretrained=True)
vgg_19
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /tmp/.torch/models/vgg19_bn-c79401a0.pth
# 100%|██████████| 574769405/574769405 [00:07<00:00, 77429292.48it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace)
#     (23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU(inplace)
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace)
#     (33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace)
#     (36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (37): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace)
#     (39): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace)
#     (43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (44): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (45): ReLU(inplace)
#     (46): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (48): ReLU(inplace)
#     (49): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (51): ReLU(inplace)
#     (52): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Freeze parameters so we don't backprop through them
for param in vgg_19.parameters():
    param.requires_grad = False

from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(25088, 1028)),
                          ('relu1', nn.ReLU()),
                          ('dropout1',nn.Dropout(0.5)),
                          ('fc2', nn.Linear(1028, 512)),
                          ('relu2', nn.ReLU()), 
                          ('dropout2',nn.Dropout(0.5)),
                          ('fc3', nn.Linear(512, 2)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
    
vgg_19.classifier = classifier

# %%
vgg_19
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace)
#     (23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU(inplace)
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace)
#     (33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace)
#     (36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (37): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace)
#     (39): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace)
#     (43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (44): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (45): ReLU(inplace)
#     (46): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (48): ReLU(inplace)
#     (49): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (50): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (51): ReLU(inplace)
#     (52): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1028, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.5)
#     (fc2): Linear(in_features=1028, out_features=512, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.5)
#     (fc3): Linear(in_features=512, out_features=2, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
criterion = nn.NLLLoss()
optimizer=torch.optim.Adam(vgg_19.parameters(),lr=0.01)

# %%
# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers,shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size,  num_workers=num_workers,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,  num_workers=num_workers)

# %%
if train_on_gpu:
    vgg_19.cuda()
# number of epochs to train the model
n_epochs = 3

valid_loss_min = np.Inf # track change in validation loss

#train_losses,valid_losses=[],[]

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    vgg_19.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = vgg_19(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    vgg_19.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = vgg_19(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    #train_losses.append(train_loss/len(train_loader.dataset))
    #valid_losses.append(valid_loss.item()/len(valid_loader.dataset)
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(vgg_19.state_dict(), 'model_vgg19.pth')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.136073 	Validation Loss: 0.152978
# Validation loss decreased (inf --> 0.152978).  Saving model ...
# Epoch: 2 	Training Loss: 0.626880 	Validation Loss: 0.195901
# Epoch: 3 	Training Loss: 0.791122 	Validation Loss: 0.767023

# %%
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size,  num_workers=num_workers,shuffle=True)
batch_size=4
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))

vgg_19.eval()
# iterate over valid data
for data, target in valid_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = vgg_19(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(valid_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.767022
#
# Test Accuracy of   cat: 98% (154/156)
# Test Accuracy of   dog: 96% (154/160)
#
# Test Accuracy (Overall): 97% (308/316)

# %%
batch_size=32
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size,  num_workers=num_workers,shuffle=True)
vgg_19.cpu()
# obtain one batch of test images
dataiter = iter(valid_loader)
images, labels = dataiter.next()

# move model inputs to cuda, if GPU available
#if train_on_gpu:
    #images = images.cuda()

# get sample outputs
output = vgg_19(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))

# %%
print("The state dict keys: \n\n", vgg_19.state_dict().keys())
# Out:
# The state dict keys:
#
#  odict_keys(['features.0.weight', 'features.0.bias', 'features.1.weight', 'features.1.bias', 'features.1.running_mean', 'features.1.running_var', 'features.1.num_batches_tracked', 'features.3.weight', 'features.3.bias', 'features.4.weight', 'features.4.bias', 'features.4.running_mean', 'features.4.running_var', 'features.4.num_batches_tracked', 'features.7.weight', 'features.7.bias', 'features.8.weight', 'features.8.bias', 'features.8.running_mean', 'features.8.running_var', 'features.8.num_batches_tracked', 'features.10.weight', 'features.10.bias', 'features.11.weight', 'features.11.bias', 'features.11.running_mean', 'features.11.running_var', 'features.11.num_batches_tracked', 'features.14.weight', 'features.14.bias', 'features.15.weight', 'features.15.bias', 'features.15.running_mean', 'features.15.running_var', 'features.15.num_batches_tracked', 'features.17.weight', 'features.17.bias', 'features.18.weight', 'features.18.bias', 'features.18.running_mean', 'features.18.running_var', 'features.18.num_batches_tracked', 'features.20.weight', 'features.20.bias', 'features.21.weight', 'features.21.bias', 'features.21.running_mean', 'features.21.running_var', 'features.21.num_batches_tracked', 'features.23.weight', 'features.23.bias', 'features.24.weight', 'features.24.bias', 'features.24.running_mean', 'features.24.running_var', 'features.24.num_batches_tracked', 'features.27.weight', 'features.27.bias', 'features.28.weight', 'features.28.bias', 'features.28.running_mean', 'features.28.running_var', 'features.28.num_batches_tracked', 'features.30.weight', 'features.30.bias', 'features.31.weight', 'features.31.bias', 'features.31.running_mean', 'features.31.running_var', 'features.31.num_batches_tracked', 'features.33.weight', 'features.33.bias', 'features.34.weight', 'features.34.bias', 'features.34.running_mean', 'features.34.running_var', 'features.34.num_batches_tracked', 'features.36.weight', 'features.36.bias', 'features.37.weight', 'features.37.bias', 'features.37.running_mean', 'features.37.running_var', 'features.37.num_batches_tracked', 'features.40.weight', 'features.40.bias', 'features.41.weight', 'features.41.bias', 'features.41.running_mean', 'features.41.running_var', 'features.41.num_batches_tracked', 'features.43.weight', 'features.43.bias', 'features.44.weight', 'features.44.bias', 'features.44.running_mean', 'features.44.running_var', 'features.44.num_batches_tracked', 'features.46.weight', 'features.46.bias', 'features.47.weight', 'features.47.bias', 'features.47.running_mean', 'features.47.running_var', 'features.47.num_batches_tracked', 'features.49.weight', 'features.49.bias', 'features.50.weight', 'features.50.bias', 'features.50.running_mean', 'features.50.running_var', 'features.50.num_batches_tracked', 'classifier.fc1.weight', 'classifier.fc1.bias', 'classifier.fc2.weight', 'classifier.fc2.bias', 'classifier.fc3.weight', 'classifier.fc3.bias'])

# %%
torch.save(vgg_19.state_dict(), 'checkpoint_97.pth')

# %% [markdown]
# vgg_19.load_state_dict(state_dict)

# %%
# Criteria NLLLoss which is recommended with Softmax final layer
criterion = nn.NLLLoss()
# Observe that all parameters are being optimized
optimizer = torch.optim.Adam(vgg_19.classifier.parameters(), lr=0.001)
# Decay LR by a factor of 0.1 every 3 epochs
scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
# Number of epochs

# %%
if train_on_gpu:
    vgg_19.cuda()
# number of epochs to train the model
n_epochs = 2

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    vgg_19.train()
    
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        scheduler.step()
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = vgg_19(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    vgg_19.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = vgg_19(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(vgg_19.state_dict(), 'model_vgg19_2.pth')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.774040 	Validation Loss: 0.744743
# Validation loss decreased (inf --> 0.744743).  Saving model ...
# Epoch: 2 	Training Loss: 1.635989 	Validation Loss: 0.726152
# Validation loss decreased (0.744743 --> 0.726152).  Saving model ...

# %%
batch_size=4
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size,  num_workers=num_workers,shuffle=True)
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))

vgg_19.eval()
# iterate over test data
for data, target in valid_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = vgg_19(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.145230
#
# Test Accuracy of   cat: 98% (1237/1250)
# Test Accuracy of   dog: 95% (1189/1250)
#
# Test Accuracy (Overall): 97% (2426/2500)

# %% [markdown]
# References
# <br>
# [Notebook](https://www.kaggle.com/pocahontas1010/cats-dogs-classifier-with-pytorch/notebook)
# <br>
# [Sorting data into subdirectories](https://www.kaggle.com/c/dog-breed-identification/discussion/48908)
# <br>
# [Model evaluation](https://www.kaggle.com/carloalbertobarbano/vgg16-transfer-learning-pytorch)
# <br>
# [Pytorch Models](https://pytorch.org/docs/stable/torchvision/models.html[Pytorch Models])
# <br>
# [Pytorch Augmetation](https://colab.research.google.com/drive/109vu3F1LTzD1gdVV6cho9fKGx7lzbFll)
